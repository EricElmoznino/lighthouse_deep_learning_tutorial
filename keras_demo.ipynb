# %% [markdown]
# # Prepare the data

# %%
import pandas as pd

df = pd.read_csv('./hourly_wages_data.csv')
df.head()
# Out:
#    wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0           5.10      0              8              21   35       1     1
# 1           4.95      0              9              42   57       1     1
# 2           6.67      0             12               1   19       0     0
# 3           4.00      0             12               4   22       0     0
# 4           7.50      0             12              17   35       0     1
#
#    south  manufacturing  construction
# 0      0              1             0
# 1      0              1             0
# 2      0              1             0
# 3      0              0             0
# 4      0              0             0

# %%
from sklearn.model_selection import  train_test_split

X = df.drop(columns=['wage_per_hour'])
y = df[['wage_per_hour']]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=27)

# %% [markdown]
# ---
# # Train a multi-layer perceptron

# %%
from tensorflow.keras.models import Sequential        # Helper to build a network from a sequence of layers
from tensorflow.keras.layers import Dense             # Fully-connected layer
from tensorflow.keras.callbacks import EarlyStopping  # To stop training early if val loss stops decreasing

# Create the model
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# Train the model
model.compile(optimizer='adam', loss='mean_squared_error')    # Builds the static computation graph
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=32, 
          callbacks=[EarlyStopping(patience=3)], verbose=1)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 0s 8ms/step - loss: 88.9915 - val_loss: 82.6151
# Epoch 2/30
# 14/14 [==============================] - 0s 3ms/step - loss: 74.3779 - val_loss: 68.1020
# Epoch 3/30
# 14/14 [==============================] - 0s 3ms/step - loss: 60.5991 - val_loss: 54.3283
# Epoch 4/30
# 14/14 [==============================] - 0s 3ms/step - loss: 46.9714 - val_loss: 39.7561
# Epoch 5/30
# 14/14 [==============================] - 0s 3ms/step - loss: 34.3659 - val_loss: 27.6741
# Epoch 6/30
# 14/14 [==============================] - 0s 3ms/step - loss: 26.3476 - val_loss: 22.2608
# Epoch 7/30
# 14/14 [==============================] - 0s 3ms/step - loss: 23.5914 - val_loss: 20.9640
# Epoch 8/30
# 14/14 [==============================] - 0s 3ms/step - loss: 23.3310 - val_loss: 20.7318
# Epoch 9/30
# 14/14 [==============================] - 0s 3ms/step - loss: 23.2728 - val_loss: 20.6363
# Epoch 10/30
# 14/14 [==============================] - 0s 3ms/step - loss: 23.1766 - val_loss: 20.6311
# Epoch 11/30
# 14/14 [==============================] - 0s 3ms/step - loss: 23.0721 - val_loss: 20.5619
# Epoch 12/30
# 14/14 [==============================] - 0s 4ms/step - loss: 23.0061 - val_loss: 20.4530
# Epoch 13/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.9082 - val_loss: 20.4134
# Epoch 14/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.8542 - val_loss: 20.4164
# Epoch 15/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.8171 - val_loss: 20.1960
# Epoch 16/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.7136 - val_loss: 20.0854
# Epoch 17/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.6817 - val_loss: 20.0376
# Epoch 18/30
# 14/14 [==============================] - 0s 2ms/step - loss: 22.7395 - val_loss: 19.6889
# Epoch 19/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.4671 - val_loss: 19.6933
# Epoch 20/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.4471 - val_loss: 19.7460
# Epoch 21/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.3601 - val_loss: 19.4381
# Epoch 22/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.1945 - val_loss: 19.3150
# Epoch 23/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.1349 - val_loss: 19.3725
# Epoch 24/30
# 14/14 [==============================] - 0s 3ms/step - loss: 22.0602 - val_loss: 18.9594
# Epoch 25/30
# 14/14 [==============================] - 0s 4ms/step - loss: 21.8487 - val_loss: 18.8365
# Epoch 26/30
# 14/14 [==============================] - 0s 3ms/step - loss: 21.7438 - val_loss: 18.7503
# Epoch 27/30
# 14/14 [==============================] - 0s 4ms/step - loss: 21.6085 - val_loss: 19.0221
# Epoch 28/30
# 14/14 [==============================] - 0s 3ms/step - loss: 21.6113 - val_loss: 18.6600
# Epoch 29/30
# 14/14 [==============================] - 0s 4ms/step - loss: 21.5239 - val_loss: 18.5698
# Epoch 30/30
# 14/14 [==============================] - 0s 3ms/step - loss: 21.4660 - val_loss: 18.4164

# %% [markdown]
# ---
# # Comparison to linear regression

# %%
# Create the model
regression = Sequential()
regression.add(Dense(1, input_shape=(X.shape[1],)))

# Train the model
regression.compile(optimizer='adam', loss='mean_squared_error')
regression.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=32, 
               callbacks=[EarlyStopping(patience=3)], verbose=1)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 0s 7ms/step - loss: 161.3015 - val_loss: 157.0056
# Epoch 2/30
# 14/14 [==============================] - 0s 3ms/step - loss: 138.8558 - val_loss: 134.8419
# Epoch 3/30
# 14/14 [==============================] - 0s 3ms/step - loss: 118.9374 - val_loss: 115.3222
# Epoch 4/30
# 14/14 [==============================] - 0s 3ms/step - loss: 101.6721 - val_loss: 98.7210
# Epoch 5/30
# 14/14 [==============================] - 0s 3ms/step - loss: 87.0941 - val_loss: 84.4360
# Epoch 6/30
